# %%
# %load_ext sql

# %%
import csv, sqlite3

con = sqlite3.connect("anything.db")
cur = con.cursor()
#!pip install -q pandas==1.1.5

# %%
# %sql sqlite:///anything.db

# %%
import pandas
df = pandas.read_csv('https://.........................jcxq-k9xf.csv')
df.to_sql("myTable", con, if_exists='replace', index=False,method="multi")

# %%
# %sql SELECT * FROM myTable;
